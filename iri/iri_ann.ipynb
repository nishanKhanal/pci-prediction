# %%
import math
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError, MeanSquaredError

from sklearn.metrics import r2_score

# %%
# x_train = features, y_train = target

df = pd.read_csv('iri-cleaned.csv')


x = df.drop('IRI',axis=1)
y = df.IRI


# Seed value
# Apparently you may use different seed values at each stage
seed_value= 0

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)
# for later versions: 
# tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
# import keras.backend.tensorflow_backend as K
# session_conf =  tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
# sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
# K.set_session(sess)
# for later versions:
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=seed_value)
# Out:
# 2023-07-26 12:53:51.762263: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 12:53:51.762504: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
def scale_datasets(x_train, x_test):

  """
  Standard Scale test and train data
  Z - Score normalization
  """
  standard_scaler = StandardScaler()
  x_train_scaled = pd.DataFrame(
      standard_scaler.fit_transform(x_train),
      columns=x_train.columns
  )
  x_test_scaled = pd.DataFrame(
      standard_scaler.transform(x_test),
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled
x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)

# %%
hidden_units1 = 48
# hidden_units2 = 12
# hidden_units3 = 12
# hidden_units1 = 160
# hidden_units2 = 480
# hidden_units3 = 256
learning_rate = 0.001
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    # Dropout(0.2),
    # Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    # Dropout(0.2),
    # Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()

# %%
# import tensorflow as tf
# from tensorflow.keras.metrics import Metric
# from tensorflow.keras import backend as K

# class R2KerasMetric(Metric):
#     def __init__(self, name='r2_keras', **kwargs):
#         super(R2KerasMetric, self).__init__(name=name, **kwargs)
#         self.r2_values = self.add_weight(name='r2_values', initializer='zeros')
#         self.total_samples = self.add_weight(name='total_samples', initializer='zeros')

#     def update_state(self, y_true, y_pred, sample_weight=None):
#         y_true_flat = tf.reshape(y_true, shape=(-1,))
#         y_pred_flat = tf.reshape(y_pred, shape=(-1,))
#         residual = y_true_flat - y_pred_flat
#         ss_res = K.sum(K.square(residual))
#         ss_tot = K.sum(K.square(y_true_flat - K.mean(y_true_flat)))
#         r2 = 1 - ss_res / (ss_tot + K.epsilon())
#         current_samples = tf.cast(tf.size(y_true), dtype=tf.float32)
#         self.r2_values.assign_add(r2 * current_samples)
#         self.total_samples.assign_add(current_samples)

#     def result(self):
#         return self.r2_values / self.total_samples

#     def reset_states(self):
#         self.r2_values.assign(0.0)
#         self.total_samples.assign(0.0)

#     # Add the variables property as required by Keras
#     @property
#     def variables(self):
#         return self._collected_trainable_weights

#     # Override the get_config method to avoid issues with serialization
#     def get_config(self):
#         return {}

# %%
# def r2_keras(y_true, y_pred):
#     r2 = r2_score(y_true, y_pred)
#     return tf.convert_to_tensor(r2, dtype=tf.float32)  # Convert the result to a tensor


# loss function
msle = MeanSquaredLogarithmicError()
mse = MeanSquaredError()
model.compile(
    loss=mse, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=['mse' ]
)

# %%
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=200, 
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s
200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.6774 - mse: 3.6774 - val_loss: 5.2897 - val_mse: 5.2897
# Epoch 47/200
# 6/6 [==============================] - 0s 8ms/step - loss: 3.6124 - mse: 3.6124 - val_loss: 5.2460 - val_mse: 5.2460
# Epoch 48/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.5485 - mse: 3.5485 - val_loss: 5.2223 - val_mse: 5.2223
# Epoch 49/200
# 6/6 [==============================] - 0s 8ms/step - loss: 3.4886 - mse: 3.4886 - val_loss: 5.1957 - val_mse: 5.1957
# Epoch 50/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.4338 - mse: 3.4338 - val_loss: 5.1952 - val_mse: 5.1952
# Epoch 51/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.3685 - mse: 3.3685 - val_loss: 5.1878 - val_mse: 5.1878
# Epoch 52/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.3215 - mse: 3.3215 - val_loss: 5.1690 - val_mse: 5.1690
# Epoch 53/200
# 6/6 [==============================] - 0s 8ms/step - loss: 3.2776 - mse: 3.2776 - val_loss: 5.1539 - val_mse: 5.1539
# Epoch 54/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.2248 - mse: 3.2248 - val_loss: 5.1415 - val_mse: 5.1415
# Epoch 55/200
# 6/6 [==============================] - 0s 8ms/step - loss: 3.1790 - mse: 3.1790 - val_loss: 5.1571 - val_mse: 5.1571
# Epoch 56/200
# 6/6 [==============================] - 0s 11ms/step - loss: 3.1396 - mse: 3.1396 - val_loss: 5.1434 - val_mse: 5.1434
# Epoch 57/200
# 6/6 [==============================] - 0s 8ms/step - loss: 3.0955 - mse: 3.0955 - val_loss: 5.1641 - val_mse: 5.1641
# Epoch 58/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.0562 - mse: 3.0562 - val_loss: 5.1607 - val_mse: 5.1607
# Epoch 59/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.0216 - mse: 3.0216 - val_loss: 5.1493 - val_mse: 5.1493
# Epoch 60/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.9827 - mse: 2.9827 - val_loss: 5.1325 - val_mse: 5.1325
# Epoch 61/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.9500 - mse: 2.9500 - val_loss: 5.1051 - val_mse: 5.1051
# Epoch 62/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.9128 - mse: 2.9128 - val_loss: 5.0864 - val_mse: 5.0864
# Epoch 63/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.8829 - mse: 2.8829 - val_loss: 5.0826 - val_mse: 5.0826
# Epoch 64/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.8501 - mse: 2.8501 - val_loss: 5.0563 - val_mse: 5.0563
# Epoch 65/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.8187 - mse: 2.8187 - val_loss: 5.0493 - val_mse: 5.0493
# Epoch 66/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.7888 - mse: 2.7888 - val_loss: 5.0513 - val_mse: 5.0513
# Epoch 67/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.7567 - mse: 2.7567 - val_loss: 5.0495 - val_mse: 5.0495
# Epoch 68/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.7305 - mse: 2.7305 - val_loss: 5.0599 - val_mse: 5.0599
# Epoch 69/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.7010 - mse: 2.7010 - val_loss: 5.0694 - val_mse: 5.0694
# Epoch 70/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.6721 - mse: 2.6721 - val_loss: 5.0654 - val_mse: 5.0654
# Epoch 71/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.6467 - mse: 2.6467 - val_loss: 5.0488 - val_mse: 5.0488
# Epoch 72/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.6196 - mse: 2.6196 - val_loss: 5.0519 - val_mse: 5.0519
# Epoch 73/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.5999 - mse: 2.5999 - val_loss: 5.0756 - val_mse: 5.0756
# Epoch 74/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.5678 - mse: 2.5678 - val_loss: 5.0698 - val_mse: 5.0698
# Epoch 75/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.5468 - mse: 2.5468 - val_loss: 5.0588 - val_mse: 5.0588
# Epoch 76/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.5253 - mse: 2.5253 - val_loss: 5.0631 - val_mse: 5.0631
# Epoch 77/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.5036 - mse: 2.5036 - val_loss: 5.0516 - val_mse: 5.0516
# Epoch 78/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.4796 - mse: 2.4796 - val_loss: 5.0390 - val_mse: 5.0390
# Epoch 79/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.4591 - mse: 2.4591 - val_loss: 5.0416 - val_mse: 5.0416
# Epoch 80/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.4440 - mse: 2.4440 - val_loss: 5.0332 - val_mse: 5.0332
# Epoch 81/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.4187 - mse: 2.4187 - val_loss: 5.0185 - val_mse: 5.0185
# Epoch 82/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.3981 - mse: 2.3981 - val_loss: 5.0345 - val_mse: 5.0345
# Epoch 83/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.3780 - mse: 2.3780 - val_loss: 5.0484 - val_mse: 5.0484
# Epoch 84/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.3662 - mse: 2.3662 - val_loss: 5.0851 - val_mse: 5.0851
# Epoch 85/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.3443 - mse: 2.3443 - val_loss: 5.0908 - val_mse: 5.0908
# Epoch 86/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.3291 - mse: 2.3291 - val_loss: 5.0906 - val_mse: 5.0906
# Epoch 87/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.3143 - mse: 2.3143 - val_loss: 5.0691 - val_mse: 5.0691
# Epoch 88/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.2903 - mse: 2.2903 - val_loss: 5.0773 - val_mse: 5.0773
# Epoch 89/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.2780 - mse: 2.2780 - val_loss: 5.0868 - val_mse: 5.0868
# Epoch 90/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.2638 - mse: 2.2638 - val_loss: 5.0641 - val_mse: 5.0641
# Epoch 91/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.2452 - mse: 2.2452 - val_loss: 5.0420 - val_mse: 5.0420
# Epoch 92/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.2285 - mse: 2.2285 - val_loss: 5.0386 - val_mse: 5.0386
# Epoch 93/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.2132 - mse: 2.2132 - val_loss: 5.0400 - val_mse: 5.0400
# Epoch 94/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.1988 - mse: 2.1988 - val_loss: 5.0152 - val_mse: 5.0152
# Epoch 95/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1850 - mse: 2.1850 - val_loss: 4.9986 - val_mse: 4.9986
# Epoch 96/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.1724 - mse: 2.1724 - val_loss: 4.9703 - val_mse: 4.9703
# Epoch 97/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1521 - mse: 2.1521 - val_loss: 4.9762 - val_mse: 4.9762
# Epoch 98/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1397 - mse: 2.1397 - val_loss: 4.9599 - val_mse: 4.9599
# Epoch 99/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.1331 - mse: 2.1331 - val_loss: 4.9817 - val_mse: 4.9817
# Epoch 100/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.1113 - mse: 2.1113 - val_loss: 4.9592 - val_mse: 4.9592
# Epoch 101/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.0962 - mse: 2.0962 - val_loss: 4.9844 - val_mse: 4.9844
# Epoch 102/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.0810 - mse: 2.0810 - val_loss: 4.9762 - val_mse: 4.9762
# Epoch 103/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.0674 - mse: 2.0674 - val_loss: 4.9604 - val_mse: 4.9604
# Epoch 104/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.0511 - mse: 2.0511 - val_loss: 4.9700 - val_mse: 4.9700
# Epoch 105/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.0381 - mse: 2.0381 - val_loss: 4.9650 - val_mse: 4.9650
# Epoch 106/200
# 6/6 [==============================] - 0s 7ms/step - loss: 2.0222 - mse: 2.0222 - val_loss: 4.9748 - val_mse: 4.9748
# Epoch 107/200
# 6/6 [==============================] - 0s 8ms/step - loss: 2.0104 - mse: 2.0104 - val_loss: 4.9799 - val_mse: 4.9799
# Epoch 108/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.9970 - mse: 1.9970 - val_loss: 4.9773 - val_mse: 4.9773
# Epoch 109/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1.9875 - mse: 1.9875 - val_loss: 4.9838 - val_mse: 4.9838
# Epoch 110/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1.
200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.5239 - mse: 1.5239 - val_loss: 4.7732 - val_mse: 4.7732
# Epoch 143/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.5105 - mse: 1.5105 - val_loss: 4.7755 - val_mse: 4.7755
# Epoch 144/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4981 - mse: 1.4981 - val_loss: 4.7748 - val_mse: 4.7748
# Epoch 145/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4831 - mse: 1.4831 - val_loss: 4.7735 - val_mse: 4.7735
# Epoch 146/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4679 - mse: 1.4679 - val_loss: 4.7622 - val_mse: 4.7622
# Epoch 147/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4540 - mse: 1.4540 - val_loss: 4.7708 - val_mse: 4.7708
# Epoch 148/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4432 - mse: 1.4432 - val_loss: 4.7635 - val_mse: 4.7635
# Epoch 149/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4265 - mse: 1.4265 - val_loss: 4.7609 - val_mse: 4.7609
# Epoch 150/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4155 - mse: 1.4155 - val_loss: 4.7559 - val_mse: 4.7559
# Epoch 151/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4001 - mse: 1.4001 - val_loss: 4.7484 - val_mse: 4.7484
# Epoch 152/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.3898 - mse: 1.3898 - val_loss: 4.7444 - val_mse: 4.7444
# Epoch 153/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.3763 - mse: 1.3763 - val_loss: 4.7768 - val_mse: 4.7768
# Epoch 154/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.3625 - mse: 1.3625 - val_loss: 4.7616 - val_mse: 4.7616
# Epoch 155/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.3525 - mse: 1.3525 - val_loss: 4.7610 - val_mse: 4.7610
# Epoch 156/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.3395 - mse: 1.3395 - val_loss: 4.7435 - val_mse: 4.7435
# Epoch 157/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.3278 - mse: 1.3278 - val_loss: 4.7299 - val_mse: 4.7299
# Epoch 158/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.3150 - mse: 1.3150 - val_loss: 4.7322 - val_mse: 4.7322
# Epoch 159/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.3022 - mse: 1.3022 - val_loss: 4.7202 - val_mse: 4.7202
# Epoch 160/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2890 - mse: 1.2890 - val_loss: 4.7502 - val_mse: 4.7502
# Epoch 161/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.2810 - mse: 1.2810 - val_loss: 4.7507 - val_mse: 4.7507
# Epoch 162/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2685 - mse: 1.2685 - val_loss: 4.7254 - val_mse: 4.7254
# Epoch 163/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.2579 - mse: 1.2579 - val_loss: 4.7316 - val_mse: 4.7316
# Epoch 164/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.2480 - mse: 1.2480 - val_loss: 4.7167 - val_mse: 4.7167
# Epoch 165/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.2357 - mse: 1.2357 - val_loss: 4.7024 - val_mse: 4.7024
# Epoch 166/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.2241 - mse: 1.2241 - val_loss: 4.7101 - val_mse: 4.7101
# Epoch 167/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1.2166 - mse: 1.2166 - val_loss: 4.7240 - val_mse: 4.7240
# Epoch 168/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.2030 - mse: 1.2030 - val_loss: 4.7023 - val_mse: 4.7023
# Epoch 169/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1.1926 - mse: 1.1926 - val_loss: 4.6930 - val_mse: 4.6930
# Epoch 170/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.1838 - mse: 1.1838 - val_loss: 4.7206 - val_mse: 4.7206
# Epoch 171/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.1726 - mse: 1.1726 - val_loss: 4.7023 - val_mse: 4.7023
# Epoch 172/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1646 - mse: 1.1646 - val_loss: 4.6943 - val_mse: 4.6943
# Epoch 173/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1540 - mse: 1.1540 - val_loss: 4.7001 - val_mse: 4.7001
# Epoch 174/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1.1448 - mse: 1.1448 - val_loss: 4.6981 - val_mse: 4.6981
# Epoch 175/200
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1357 - mse: 1.1357 - val_loss: 4.6927 - val_mse: 4.6927
# Epoch 176/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1258 - mse: 1.1258 - val_loss: 4.6618 - val_mse: 4.6618
# Epoch 177/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1174 - mse: 1.1174 - val_loss: 4.6617 - val_mse: 4.6617
# Epoch 178/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1109 - mse: 1.1109 - val_loss: 4.6610 - val_mse: 4.6610
# Epoch 179/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1010 - mse: 1.1010 - val_loss: 4.6778 - val_mse: 4.6778
# Epoch 180/200
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0957 - mse: 1.0957 - val_loss: 4.7020 - val_mse: 4.7020
# Epoch 181/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0845 - mse: 1.0845 - val_loss: 4.6829 - val_mse: 4.6829
# Epoch 182/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0772 - mse: 1.0772 - val_loss: 4.7000 - val_mse: 4.7000
# Epoch 183/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0658 - mse: 1.0658 - val_loss: 4.6891 - val_mse: 4.6891
# Epoch 184/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0612 - mse: 1.0612 - val_loss: 4.6845 - val_mse: 4.6845
# Epoch 185/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0513 - mse: 1.0513 - val_loss: 4.6965 - val_mse: 4.6965
# Epoch 186/200
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0430 - mse: 1.0430 - val_loss: 4.6931 - val_mse: 4.6931
# Epoch 187/200
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0364 - mse: 1.0364 - val_loss: 4.6618 - val_mse: 4.6618
# Epoch 188/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0288 - mse: 1.0288 - val_loss: 4.6502 - val_mse: 4.6502
# Epoch 189/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0197 - mse: 1.0197 - val_loss: 4.6526 - val_mse: 4.6526
# Epoch 190/200
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0138 - mse: 1.0138 - val_loss: 4.6349 - val_mse: 4.6349
# Epoch 191/200
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0062 - mse: 1.0062 - val_loss: 4.6396 - val_mse: 4.6396
# Epoch 192/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9998 - mse: 0.9998 - val_loss: 4.6504 - val_mse: 4.6504
# Epoch 193/200
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9935 - mse: 0.9935 - val_loss: 4.6670 - val_mse: 4.6670
# Epoch 194/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9875 - mse: 0.9875 - val_loss: 4.6812 - val_mse: 4.6812
# Epoch 195/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.9786 - mse: 0.9786 - val_loss: 4.6855 - val_mse: 4.6855
# Epoch 196/200
# 6/6 [==============================] - 0s 10ms/step - loss: 0.9730 - mse: 0.9730 - val_loss: 4.6937 - val_mse: 4.6937
# Epoch 197/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9665 - mse: 0.9665 - val_loss: 4.7160 - val_mse: 4.7160
# Epoch 198/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9617 - mse: 0.9617 - val_loss: 4.7144 - val_mse: 4.7144
# Epoch 199/200
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9548 - mse: 0.9548 - val_loss: 4.7036 - val_mse: 4.7036
# Epoch 200/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.9495 - mse: 0.9495 - val_loss: 4.6549 - val_mse: 4.6549

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mse')

# %%
tf.__version__
# Out:
# '2.13.0'

# %%
x_test['prediction'] = model.predict(x_test_scaled)
model.evaluate(x_test_scaled,y_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 4ms/step - loss: 5.9616 - mse: 5.9616
# [5.961575508117676, 5.961575508117676]

# %%
tf.__version__

test_mse = model.evaluate(x_test_scaled,y_test)[0]
import numpy as np
1- test_mse / np.var(y)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 5.9616 - mse: 5.9616
# 0.13735611224116362
